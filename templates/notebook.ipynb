# %% [markdown]
# # {{notebook.title}}
#
# > Auto-generated by `/vbd-lab-{{module.id}}`. Verified against Microsoft Learn on {{freshness.last_verified}}.
#
# **Learning objectives:**
# {% for o in notebook.objectives %}- {{o}}
# {% endfor %}

# %% [markdown]
# ## Setup
#
# Run once — imports and workspace context.

# %%
# {{notebook.setup_comment}}
{{notebook.setup_code}}

# %% [markdown]
# ## Exercises
#
# Each cell has a TODO. Solutions are in `../../solutions/` (if enabled).
